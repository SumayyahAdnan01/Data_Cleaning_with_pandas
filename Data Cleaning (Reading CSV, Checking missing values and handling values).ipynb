# %% [markdown]
# # Data Cleaning (Reading CSV, Checking missing values and handling values)

# %%
#Reading all the data in CSV file on the desktop
df_data = pd.read_csv("Desktop/Building_Permits.csv")

# %%
import pandas as pd
import numpy as np

# %%
#Set seed for reproducibility
np.random.seed(0)

# %%
#Look at the first 20 row from the df_data
df_data.head(20)
# Out:
#    Permit Number  Permit Type            Permit Type Definition  \
# 0   201505065519            4                      sign - erect
# 1   201604195146            4                      sign - erect
# 2   201605278609            3  additions alterations or repairs
# 3   201611072166            8            otc alterations permit
# 4   201611283529            6                       demolitions
# 5   201706149344            8            otc alterations permit
# 6   201706300814            8            otc alterations permit
# 7        M803667            8            otc alterations permit
# 8        M804227            8            otc alterations permit
# 9        M804767            8            otc alterations permit
# 10       M805287            8            otc alterations permit
# 11       M805907            8            otc alterations permit
# 12       M806447            8            otc alterations permit
# 13  201707252846            8            otc alterations permit
# ...

# %%
#Getting the number of missing data points per column
missing_values_count = df_data.isnull().sum()
missing_values_count[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
#Calculating missing data
total_cells = np.product(df_data.shape)
total_missing = missing_values_count.sum()

# %%
#Getting the percentage of missing data
percent_missing = (total_missing/total_cells)*(100)
print(percent_missing)
# Out:
# 26.26002315058403

# %%
#Look at the number of the missing values in the first ten columns
missing_values_count[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
#Removes all the rows that contain missing values
#This would remove all the data!!
df_data.dropna()

# %%
#Removes all columns with at all one missing values
columns_with_na_dropped = df_data.dropna(axis=1)

# %%
#Display the header without the missing values
columns_with_na_dropped.head(10)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
# 5  201706149344            8            otc alterations permit
# 6  201706300814            8            otc alterations permit
# 7       M803667            8            otc alterations permit
# 8       M804227            8            otc alterations permit
# 9       M804767            8            otc alterations permit
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# ...

# %%
#Checking columns on the original dataset
print("Columns in original dataset: %d \n" %df_data.shape[1])
# Out:
# Columns in original dataset: 43

# %%
#Checking on the columns wwith lost from the dataset
print("Columns with na dropped: %d \n" %columns_with_na_dropped.shape[1])
# Out:
# Columns with na dropped: 12

# %% [markdown]
# # Fills the missing values automatically

# %%
#Get the small subset of the Building permit dataset
subset_df_data = df_data.loc[:, 'Street Number':'Record ID'].head(20)
subset_df_data
# Out:
#     Street Number Street Number Suffix Street Name Street Suffix   Unit  \
# 0             140                  NaN       Ellis            St    NaN
# 1             440                  NaN       Geary            St    0.0
# 2            1647                  NaN     Pacific            Av    NaN
# 3            1230                  NaN     Pacific            Av    0.0
# 4             950                  NaN      Market            St    NaN
# 5             800                  NaN     Indiana            St    NaN
# 6            1291                  NaN        11th            Av    0.0
# 7            1465                  NaN      Revere            Av    NaN
# 8            2094                  NaN        Fell            St    NaN
# 9              89                  NaN      Alpine            Tr    NaN
# 10            106                  NaN     Sanchez            St    NaN
# 11            675                  NaN        Fell            St    NaN
# ...

# %%
#FIlling missing data with "-"
subset_df_data.fillna('-')
# Out:
#     Street Number Street Number Suffix Street Name Street Suffix Unit  \
# 0             140                    -       Ellis            St    -
# 1             440                    -       Geary            St    0
# 2            1647                    -     Pacific            Av    -
# 3            1230                    -     Pacific            Av    0
# 4             950                    -      Market            St    -
# 5             800                    -     Indiana            St    -
# 6            1291                    -        11th            Av    0
# 7            1465                    -      Revere            Av    -
# 8            2094                    -        Fell            St    -
# 9              89                    -      Alpine            Tr    -
# 10            106                    -     Sanchez            St    -
# 11            675                    -        Fell            St    -
# ...

# %%
# replace all NA's the value that comes directly after it in the same column, 
# then replace all the remaining na's with '-'
subset_df_data.fillna(method='bfill', axis=0).fillna('-')
# Out:
#     Street Number Street Number Suffix Street Name Street Suffix   Unit  \
# 0             140                    -       Ellis            St    0.0
# 1             440                    -       Geary            St    0.0
# 2            1647                    -     Pacific            Av    0.0
# 3            1230                    -     Pacific            Av    0.0
# 4             950                    -      Market            St    0.0
# 5             800                    -     Indiana            St    0.0
# 6            1291                    -        11th            Av    0.0
# 7            1465                    -      Revere            Av  301.0
# 8            2094                    -        Fell            St  301.0
# 9              89                    -      Alpine            Tr  301.0
# 10            106                    -     Sanchez            St  301.0
# 11            675                    -        Fell            St  301.0
# ...
